# %%
from datasets import load_dataset

# Load CSV
dataset = load_dataset("csv", data_files="instruction.csv", split="train")

# Split 90% train, 10% validation
split_dataset = dataset.train_test_split(test_size=0.1, shuffle=True, seed=42)

train_dataset = split_dataset['train']
val_dataset = split_dataset['test']

train_dataset.to_csv('train.csv')
val_dataset.to_csv('val.csv')
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Creating CSV from Arrow format:   0%|          | 0/57 [00:00<?, ?ba/s]
# Creating CSV from Arrow format:   0%|          | 0/7 [00:00<?, ?ba/s]
# 1732075
