# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained("VietAI/vit5-large")

# Load model
model = AutoModelForSeq2SeqLM.from_pretrained("VietAI/vit5-large")

# %%
model.eval()
text = "translate Vietnamese to English: Việt Nam là một quốc gia ở Đông Nam Á."

inputs = tokenizer(text, return_tensors="pt")
outputs = model.generate(**inputs, max_length=50)

result = tokenizer.decode(outputs[0], skip_special_tokens=True)
print(result)
# Out:
# :+: Vietnameseor: Vietnamese: Vietnamese:_: Vietnam:Z: Vietnamese: Vietnam

# %%
print('hello')
# Out:
# hello
