# %%
from transformers import MarianMTModel, MarianTokenizer

# Vietnamese to English model from OPUS-MT
model_name = "Helsinki-NLP/opus-mt-vi-en"

tokenizer = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(model_name)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 6
#       3 # Vietnamese to English model from OPUS-MT
#       4 model_name = "Helsinki-NLP/opus-mt-vi-en"
# ----> 6 tokenizer = MarianTokenizer.from_pretrained(model_name)
#       7 model = MarianMTModel.from_pretrained(model_name)
#
# File ~\miniconda3\envs\ai\lib\site-packages\transformers\utils\import_utils.py:2142, in DummyObject.__getattribute__(cls, key)
#    2140 if (key.startswith("_") and key != "_from_config") or key == "is_dummy" or key == "mro" or key == "call":
#    2141     return super().__getattribute__(key)
# -> 2142 requires_backends(cls, cls._backends)
#
# File ~\miniconda3\envs\ai\lib\site-packages\transformers\utils\import_utils.py:2128, in requires_backends(obj, backends)
#    2125         failed.append(msg.format(name))
#    2127 if failed:
# -> 2128     raise ImportError("".join(failed))
#
# ImportError:
# MarianTokenizer requires the SentencePiece library but it was not found in your environment. Check out the instructions on the
# installation page of its repo: https://github.com/google/sentencepiece#installation and follow the ones
# that match your environment. Please note that you may need to restart your runtime after installation.

# %%
def translate_vi_to_en(text):
    # Tokenize
    inputs = tokenizer(text, return_tensors="pt", padding=True)
    # Generate translation
    translated = model.generate(**inputs)
    # Decode
    return tokenizer.decode(translated[0], skip_special_tokens=True)

text_vi = "Tôi yêu lập trình"
text_en = translate_vi_to_en(text_vi)
print(text_en)  # Output: "I love programming"
