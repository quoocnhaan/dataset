# %%
from datasets import load_dataset

data_files = {"train": "instruction/train.csv", "validation": "instruction/val.csv"}
# \t is the tab character in Python
datasets = load_dataset("csv", data_files=data_files, delimiter=",")
print(datasets)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Instruction', 'Input', 'Answer', 'Task'],
#         num_rows: 50645
#     })
#     validation: Dataset({
#         features: ['Instruction', 'Input', 'Answer', 'Task'],
#         num_rows: 12662
#     })
# })
